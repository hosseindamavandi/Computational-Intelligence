# %%
import random
import numpy as np
import matplotlib.pyplot as plt

# %%
sx = 1000

# %%
class Queens:
    
    def __init__(self, rows):
        self.rows = rows
        self.h = fitness_value(rows)
        self.rowsbin = to_binary(rows)

# %%
def fitness_value(rows):
    value = 0
    for i in range(0,len(rows)) :
        for j in range(i+1,len(rows)) :
            if (rows[i]==rows[j]) or (abs(rows[i]-rows[j]) == abs(i-j)) :
                value += 1

    return value

# %%
a=[1, 4, 7, 5, 2, 0, 6, 3]
fitness_value(a)
# Out:
# 1

# %%
def to_binary(rows):
    rows_bin = ''
    for i in range(0,len(rows)) :
        r_bin = "{0:b}".format(int(rows[i]))
        while len(r_bin) < 3 :
            r_bin = '0' + r_bin
        
        rows_bin = rows_bin + r_bin
        
    return rows_bin

# %%
a=[4,0,7,3,1,6,2,5]
to_binary(a)
# Out:
# '100000111011001110010101'

# %%
def to_decimal(rows_bin) :
    
    rows = []
    for i in range(0,len(rows_bin),3):
        temp = rows_bin[i:i+3]
        temp = int(temp, 2)
        rows.append(temp)
        
    return rows

# %%
a='100000111011001110010101'
to_decimal(a)
# Out:
# [4, 0, 7, 3, 1, 6, 2, 5]

# %%
def first_population(size):
    population = []
    for i in range(size):
        row = []
        for j in range(0,8) :
            row.append(random.randint(0 , 7))
            
        population.append(Queens(row))
    
    return population

# %%
a=first_population(2)
print(a[0].rows,"@",a[1].rows)
# Out:
# [1, 0, 2, 1, 3, 2, 1, 2] @ [6, 3, 4, 0, 0, 7, 4, 0]

# %%
def select_parents(population,size):
    
    All_Parent = []
    sort_population = []
    weights = []
    sort_population = sorted(population, key=lambda p: p.h, reverse=True)
    
    for i in range(len(sort_population)):
        weights.append(i+1)
    
    All_Parent = random.choices(sort_population, weights = weights , k = size)
        
    return All_Parent

# %%
def select_parents_computation(population,size):
    
    All_Parent = []
    sort_population = []
    
    for i in range(0,size) :
        temp_population = population.copy()
        random_population = []
        for j in range(0,len(population)//5) :
            index = random.randint(0,len(population)-1-j)
            random_population.append(temp_population[index])
            temp_population.pop(index)
            
        sort_population = sorted(random_population, key=lambda p: p.h, reverse=False)
        All_Parent.append(sort_population[0])
    
        
    return All_Parent

# %%
def cross_over(parents) : 
    childeren = []
    for i in range(0,len(parents)-1) :

#        rowbin_child1 = cross_one_point(parents[i].rowsbin, parents[i+1].rowsbin)
        rowbin_child1 = cross_uniform(parents[i].rowsbin, parents[i+1].rowsbin)
        rowbin_child2 = rowbin_child1[::-1]
        
        row_child1 = to_decimal(rowbin_child1)
        row_child2 = to_decimal(rowbin_child2)
        
        childeren.append(Queens(row_child1))
        childeren.append(Queens(row_child2))
        
        i += 1
        
    return childeren

# %%
def cross_one_point(parent1, parent2) :
    index = random.randint(1,23)
    child = ''

    for i in range(0,len(parent1)) :
        if i < index :
            child = child + parent1[i]
        else :
            child = child + parent2[i]
    
    return child

# %%
cross_one_point('100000111011001110010101','101100111011001010010001')
# Out:
# '100000111011001010010001'

# %%
def cross_uniform(parent1, parent2) :
    child = ''

    for i in range(0,len(parent1)) :
        if random.choice(['1', '2']) == '1' :
            child = child + parent1[i]
        else :
            child = child + parent2[i]
    
    return child

# %%
def mutate(childeren):
    mutatant = childeren
    
    for i in range(0,len(mutatant)) :
        index = random.randint(0,len(mutatant[i].rowsbin)-1)
        if random.random() < 0.2:
            b = random.choice(['0', '1'])
            mutatant[i].rowsbin = mutatant[i].rowsbin[:index] + b + mutatant[i].rowsbin[index+1:]
    
    return mutatant

# %%
def replacement(population, parents, childeren) :
    population_copy = population.copy()
    parents_copy = parents.copy()
    childeren_copy = childeren.copy()
    
    newlistChild = []
    newlistParent = []
    newlistChild = sorted(childeren_copy, key=lambda ch: ch.h, reverse=False)      #STEP 6
    newlistParent = sorted(parents_copy, key=lambda p: p.h, reverse=True)

    for i in range(0,int((len(parents_copy)*30/100)+0.5)) :
        newlistParent[i] = newlistChild[i]
    
    newpopulation = newlistParent
#     sort_pop = sorted(population_copy, key=lambda p: p.h, reverse=True)
    
    for i in range(0,len(newpopulation)) :
        index = random.randint(0,len(population)-1)
        population[index] = newpopulation[i]
        
    return population

# %%
def select(population, size) :
    random_population = []    
    
    temp_population = population.copy()
    random_population = []
    
    for i in range(0,size) :
        index = random.randint(0,len(population)-1-i)
        random_population.append(temp_population[index])
        temp_population.pop(index)
            
        
    return random_population

# %%
def replacement2(population, parents, childeren) :
    population_copy = population.copy()
    parents_copy = parents.copy()
    childeren_copy = childeren.copy()
    
    newlistChild = []
    newlistParent = []
    newpopulation = []

    newlistChild = select(childeren_copy,(len(childeren_copy)*30//100))
    newlistParent = select(parents_copy,(len(parents_copy)*70//100))
    
    for i in range(0,len(newlistParent)) :
        newpopulation.append(newlistParent[i])
    
    for i in range(0,len(newlistChild)) :
        newpopulation.append(newlistChild[i])
        
    for i in range(0,len(newpopulation)) :
        index = random.randint(0,len(population)-1)
        population[index] = newpopulation[i]
        
    return population

# %%
def GetBest(population) :
    pop = sorted(population, key=lambda ch: ch.h, reverse=False)
    k=0
    print("\nposition of Queens :",pop[0].rows,"\n")
    
    rows, cols = (8, 8)
 
    arr = [['_' for i in range(cols)] for j in range(rows)]

    for i in range(0,8) :
        arr[7-pop[0].rows[i]][i] = 'Q'
        
#     for i in range(0,8) :
#         for j in range(0,8) :
#             print(arr[i][j],end="  ")
#         print("\n")

    for row in arr:
        print(row)
        
    return pop[0].h

# %%
def print_pop(population) :
    for i in range(0,len(population)) :
        print(population[i].rows,"  h=",population[i].h)

# %%
def main():
    draw_fitness = []    #for draw result
    cnt=0      # for count number of repeat best in generations
    Best=28   # maximum of 8 queen
    gen=0      # for count number of generations
    target=0   # minimum of 8 queen
    
    firstpopulation = first_population(sx)   #STEP 1
    current_population = firstpopulation    #STEP 2
    
    while True :
        parents = select_parents(current_population,sx//4)   #STEP 3
#        parents = select_parents_computation(current_population,sx//4)   #STEP 3

        childeren = cross_over(parents)      #STEP 4

        childeren = mutate(childeren)        #STEP 5
        
        next_population = replacement2(current_population, parents, childeren)  #STEP 6        

        BestNew = GetBest(current_population)      #STEP 7
        
        if Best == BestNew :
            cnt += 1
        elif Best > BestNew :
            cnt=0
            Best = BestNew
        else :
            cnt = 0
        
        print('gen :', gen)
        print("Best (in gen ",gen,") :",Best)
        print("********************")
        draw_fitness.append(Best)
        if Best == target :
            break
            
        current_population = next_population
        gen += 1
    hist = draw_fitness
    plt.plot(hist)

# %%
main()
# Out:
# position of Queens : [2, 4, 1, 7, 0, 3, 5, 7]
#
# ['_', '_', '_', 'Q', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# gen : 0
# Best (in gen  0 ) : 2
# ********************
#
# position of Queens : [0, 3, 7, 4, 1, 1, 4, 6]
#
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', 'Q', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', 'Q', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# gen : 1
# Best (in gen  1 ) : 2
# ********************
#
# position of Queens : [0, 3, 7, 4, 1, 1, 4, 6]
#
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', 'Q', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', 'Q', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# gen : 2
# Best (in gen  2 ) : 2
# ********************
#
# position of Queens : [0, 3, 7, 4, 1, 1, 4, 6]
#
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', 'Q', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', 'Q', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# gen : 3
# Best (in gen  3 ) : 2
# ********************
#
# position of Queens : [0, 3, 7, 4, 1, 1, 4, 6]
#
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', 'Q', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', 'Q', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# gen : 4
# Best (in gen  4 ) : 2
# ********************
#
# position of Queens : [0, 3, 7, 4, 1, 1, 4, 6]
#
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', 'Q', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', 'Q', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# gen : 5
# Best (in gen  5 ) : 2
# ********************
#
# position of Queens : [7, 2, 5, 3, 0, 0, 4, 1]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', 'Q', 'Q', '_', '_']
# gen : 6
# Best (in gen  6 ) : 2
# ********************
#
# position of Queens : [2, 7, 2, 4, 1, 6, 0, 3]
#
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['Q', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# gen : 7
# Best (in gen  7 ) : 2
# ********************
#
# position of Queens : [5, 7, 3, 1, 7, 4, 6, 0]
#
# ['_', 'Q', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# gen : 8
# Best (in gen  8 ) : 2
# ********************
#
# position of Queens : [5, 3, 0, 4, 7, 1, 3, 7]
#
# ['_', '_', '_', '_', 'Q', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# gen : 9
# Best (in gen  9 ) : 2
# ********************
#
# position of Queens : [5, 7, 3, 1, 7, 4, 6, 0]
#
# ['_', 'Q', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# gen : 10
# Best (in gen  10 ) : 2
# ********************
#
# position of Queens : [4, 7, 3, 0, 6, 1, 1, 2]
#
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', 'Q', 'Q', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# gen : 11
# Best (in gen  11 ) : 2
# ********************
#
# position of Queens : [5, 7, 3, 1, 7, 4, 6, 0]
#
# ['_', 'Q', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# gen : 12
# Best (in gen  12 ) : 2
# ********************
#
# position of Queens : [5, 7, 3, 1, 7, 4, 6, 0]
#
# ['_', 'Q', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# gen : 13
# Best (in gen  13 ) : 2
# ********************
#
# position of Queens : [5, 7, 3, 1, 7, 4, 6, 0]
#
# ['_', 'Q', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# gen : 14
# Best (in gen  14 ) : 2
# ********************
#
# position of Queens : [4, 2, 7, 5, 3, 0, 6, 4]
#
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# gen : 15
# Best (in gen  15 ) : 1
# ********************
#
# position of Queens : [4, 2, 7, 5, 3, 0, 6, 4]
#
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# gen : 16
# Best (in gen  16 ) : 1
# ********************
#
# position of Queens : [5, 3, 0, 4, 7, 1, 3, 7]
#
# ['_', '_', '_', '_', 'Q', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# gen : 17
# Best (in gen  17 ) : 1
# ********************
#
# position of Queens : [5, 3, 0, 4, 7, 1, 3, 7]
#
# ['_', '_', '_', '_', 'Q', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# gen : 18
# Best (in gen  18 ) : 1
# ********************
#
# position of Queens : [5, 3, 0, 4, 7, 1, 3, 7]
#
# ['_', '_', '_', '_', 'Q', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# gen : 19
# Best (in gen  19 ) : 1
# ********************
#
# position of Queens : [5, 3, 0, 4, 7, 1, 3, 7]
#
# ['_', '_', '_', '_', 'Q', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# gen : 20
# Best (in gen  20 ) : 1
# ********************
#
# position of Queens : [5, 3, 0, 4, 7, 1, 3, 7]
#
# ['_', '_', '_', '_', 'Q', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# gen : 21
# Best (in gen  21 ) : 1
# ********************
#
# position of Queens : [5, 3, 0, 4, 7, 1, 3, 7]
#
# ['_', '_', '_', '_', 'Q', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# gen : 22
# Best (in gen  22 ) : 1
# ********************
#
# position of Queens : [5, 3, 0, 4, 7, 1, 3, 7]
#
# ['_', '_', '_', '_', 'Q', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# gen : 23
# Best (in gen  23 ) : 1
# ********************
#
# position of Queens : [0, 7, 3, 6, 0, 7, 1, 4]
#
# ['_', 'Q', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['Q', '_', '_', '_', 'Q', '_', '_', '_']
# gen : 24
# Best (in gen  24 ) : 1
# ********************
#
# position of Queens : [5, 3, 0, 4, 7, 1, 3, 7]
#
# ['_', '_', '_', '_', 'Q', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# gen : 25
# Best (in gen  25 ) : 1
# ********************
#
# position of Queens : [3, 1, 6, 4, 2, 0, 5, 7]
#
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# gen : 26
# Best (in gen  26 ) : 1
# ********************
#
# position of Queens : [5, 7, 3, 1, 7, 4, 6, 0]
#
# ['_', 'Q', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# gen : 27
# Best (in gen  27 ) : 1
# ********************
#
# position of Queens : [5, 7, 3, 1, 7, 4, 6, 0]
#
# ['_', 'Q', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# gen : 28
# Best (in gen  28 ) : 1
# ********************
#
# position of Queens : [5, 7, 3, 1, 7, 4, 6, 0]
#
# ['_', 'Q', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# gen : 29
# Best (in gen  29 ) : 1
# ********************
#
# position of Queens : [5, 7, 3, 1, 7, 4, 6, 0]
#
# ['_', 'Q', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# gen : 30
# Best (in gen  30 ) : 1
# ********************
#
# position of Queens : [5, 7, 3, 1, 7, 4, 6, 0]
#
# ['_', 'Q', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# gen : 31
# Best (in gen  31 ) : 1
# ********************
#
# position of Queens : [7, 4, 6, 0, 5, 1, 4, 6]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# gen : 32
# Best (in gen  32 ) : 1
# ********************
#
# position of Queens : [7, 4, 6, 0, 5, 1, 4, 6]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# gen : 33
# Best (in gen  33 ) : 1
# ********************
#
# position of Queens : [7, 4, 6, 0, 5, 1, 4, 6]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# gen : 34
# Best (in gen  34 ) : 1
# ********************
#
# position of Queens : [7, 4, 6, 0, 5, 1, 4, 6]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# gen : 35
# Best (in gen  35 ) : 1
# ********************
#
# position of Queens : [7, 4, 6, 0, 5, 1, 4, 6]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# gen : 36
# Best (in gen  36 ) : 1
# ********************
#
# position of Queens : [7, 4, 6, 0, 5, 1, 4, 6]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# gen : 37
# Best (in gen  37 ) : 1
# ********************
#
# position of Queens : [7, 4, 6, 0, 5, 1, 4, 6]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# gen : 38
# Best (in gen  38 ) : 1
# ********************
#
# position of Queens : [7, 4, 6, 0, 5, 1, 4, 6]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# gen : 39
# Best (in gen  39 ) : 1
# ********************
#
# position of Queens : [5, 3, 1, 7, 4, 6, 3, 5]
#
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# gen : 40
# Best (in gen  40 ) : 1
# ********************
#
# position of Queens : [5, 3, 1, 7, 4, 6, 3, 5]
#
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# gen : 41
# Best (in gen  41 ) : 1
# ********************
#
# position of Queens : [1, 5, 0, 2, 7, 5, 3, 0]
#
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', 'Q']
# gen : 42
# Best (in gen  42 ) : 1
# ********************
#
# position of Queens : [5, 3, 0, 4, 7, 1, 3, 7]
#
# ['_', '_', '_', '_', 'Q', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# gen : 43
# Best (in gen  43 ) : 1
# ********************
#
# position of Queens : [5, 3, 0, 4, 7, 1, 3, 7]
#
# ['_', '_', '_', '_', 'Q', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# gen : 44
# Best (in gen  44 ) : 1
# ********************
#
# position of Queens : [5, 3, 0, 4, 7, 1, 3, 7]
#
# ['_', '_', '_', '_', 'Q', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# gen : 45
# Best (in gen  45 ) : 1
# ********************
#
# position of Queens : [5, 3, 0, 4, 7, 1, 3, 7]
#
# ['_', '_', '_', '_', 'Q', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# gen : 46
# Best (in gen  46 ) : 1
# ********************
#
# position of Queens : [5, 3, 0, 4, 7, 1, 3, 7]
#
# ['_', '_', '_', '_', 'Q', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# gen : 47
# Best (in gen  47 ) : 1
# ********************
#
# position of Queens : [5, 3, 0, 4, 7, 1, 3, 7]
#
# ['_', '_', '_', '_', 'Q', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# gen : 48
# Best (in gen  48 ) : 1
# ********************
#
# position of Queens : [1, 5, 0, 2, 7, 5, 3, 0]
#
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', 'Q']
# gen : 49
# Best (in gen  49 ) : 1
# ********************
#
# position of Queens : [3, 6, 0, 2, 0, 5, 7, 4]
#
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', 'Q', '_', '_', '_']
# gen : 50
# Best (in gen  50 ) : 1
# ********************
#
# position of Queens : [6, 2, 3, 6, 0, 7, 1, 4]
#
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['Q', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# gen : 51
# Best (in gen  51 ) : 1
# ********************
#
# position of Queens : [7, 4, 6, 0, 5, 1, 4, 6]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# gen : 52
# Best (in gen  52 ) : 1
# ********************
#
# position of Queens : [6, 2, 3, 6, 0, 7, 1, 4]
#
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['Q', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# gen : 53
# Best (in gen  53 ) : 1
# ********************
#
# position of Queens : [7, 4, 6, 0, 5, 1, 4, 6]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# gen : 54
# Best (in gen  54 ) : 1
# ********************
#
# position of Queens : [7, 4, 6, 0, 5, 1, 4, 6]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# gen : 55
# Best (in gen  55 ) : 1
# ********************
#
# position of Queens : [7, 4, 6, 0, 5, 1, 4, 6]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# gen : 56
# Best (in gen  56 ) : 1
# ********************
#
# position of Queens : [7, 4, 6, 0, 5, 1, 4, 6]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# gen : 57
# Best (in gen  57 ) : 1
# ********************
#
# position of Queens : [7, 4, 6, 0, 5, 1, 4, 6]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# gen : 58
# Best (in gen  58 ) : 1
# ********************
#
# position of Queens : [7, 4, 6, 0, 5, 1, 4, 6]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# gen : 59
# Best (in gen  59 ) : 1
# ********************
#
# position of Queens : [6, 2, 3, 6, 0, 7, 1, 4]
#
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['Q', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# gen : 60
# Best (in gen  60 ) : 1
# ********************
#
# position of Queens : [7, 4, 6, 0, 5, 1, 4, 6]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# gen : 61
# Best (in gen  61 ) : 1
# ********************
#
# position of Queens : [5, 3, 0, 4, 7, 1, 3, 7]
#
# ['_', '_', '_', '_', 'Q', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# gen : 62
# Best (in gen  62 ) : 1
# ********************
#
# position of Queens : [7, 4, 6, 0, 5, 1, 4, 6]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# gen : 63
# Best (in gen  63 ) : 1
# ********************
#
# position of Queens : [1, 3, 1, 4, 7, 0, 2, 5]
#
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['Q', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# gen : 64
# Best (in gen  64 ) : 1
# ********************
#
# position of Queens : [1, 3, 1, 4, 7, 0, 2, 5]
#
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['Q', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# gen : 65
# Best (in gen  65 ) : 1
# ********************
#
# position of Queens : [1, 3, 1, 4, 7, 0, 2, 5]
#
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['Q', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# gen : 66
# Best (in gen  66 ) : 1
# ********************
#
# position of Queens : [1, 3, 1, 4, 7, 0, 2, 5]
#
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['Q', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# gen : 67
# Best (in gen  67 ) : 1
# ********************
#
# position of Queens : [6, 2, 3, 6, 0, 7, 1, 4]
#
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['Q', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# gen : 68
# Best (in gen  68 ) : 1
# ********************
#
# position of Queens : [6, 2, 3, 6, 0, 7, 1, 4]
#
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['Q', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# gen : 69
# Best (in gen  69 ) : 1
# ********************
#
# position of Queens : [7, 4, 6, 0, 5, 1, 4, 6]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# gen : 70
# Best (in gen  70 ) : 1
# ********************
#
# position of Queens : [1, 3, 1, 4, 7, 0, 2, 5]
#
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['Q', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# gen : 71
# Best (in gen  71 ) : 1
# ********************
#
# position of Queens : [1, 3, 1, 4, 7, 0, 2, 5]
#
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['Q', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# gen : 72
# Best (in gen  72 ) : 1
# ********************
#
# position of Queens : [1, 3, 1, 4, 7, 0, 2, 5]
#
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['Q', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# gen : 73
# Best (in gen  73 ) : 1
# ********************
#
# position of Queens : [1, 3, 1, 4, 7, 0, 2, 5]
#
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['Q', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# gen : 74
# Best (in gen  74 ) : 1
# ********************
#
# position of Queens : [1, 3, 1, 4, 7, 0, 2, 5]
#
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['Q', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# gen : 75
# Best (in gen  75 ) : 1
# ********************
#
# position of Queens : [3, 2, 6, 5, 0, 4, 1, 7]
#
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# gen : 76
# Best (in gen  76 ) : 1
# ********************
#
# position of Queens : [1, 3, 1, 4, 7, 0, 2, 5]
#
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['Q', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# gen : 77
# Best (in gen  77 ) : 1
# ********************
#
# position of Queens : [6, 2, 3, 6, 0, 7, 1, 4]
#
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['Q', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# gen : 78
# Best (in gen  78 ) : 1
# ********************
#
# position of Queens : [1, 3, 1, 4, 7, 0, 2, 5]
#
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['Q', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# gen : 79
# Best (in gen  79 ) : 1
# ********************
#
# position of Queens : [6, 2, 3, 6, 0, 7, 1, 4]
#
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['Q', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# gen : 80
# Best (in gen  80 ) : 1
# ********************
#
# position of Queens : [1, 7, 2, 0, 6, 4, 0, 5]
#
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', 'Q', '_']
# gen : 81
# Best (in gen  81 ) : 1
# ********************
#
# position of Queens : [1, 7, 2, 0, 6, 4, 0, 5]
#
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', 'Q', '_']
# gen : 82
# Best (in gen  82 ) : 1
# ********************
#
# position of Queens : [0, 5, 3, 6, 2, 7, 1, 4]
#
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# gen : 83
# Best (in gen  83 ) : 1
# ********************
#
# position of Queens : [0, 5, 3, 6, 2, 7, 1, 4]
#
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# gen : 84
# Best (in gen  84 ) : 1
# ********************
#
# position of Queens : [0, 5, 3, 6, 2, 7, 1, 4]
#
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# gen : 85
# Best (in gen  85 ) : 1
# ********************
#
# position of Queens : [0, 5, 3, 6, 2, 7, 1, 4]
#
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# gen : 86
# Best (in gen  86 ) : 1
# ********************
#
# position of Queens : [0, 5, 3, 6, 2, 7, 1, 4]
#
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# gen : 87
# Best (in gen  87 ) : 1
# ********************
#
# position of Queens : [0, 5, 3, 6, 2, 7, 1, 4]
#
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# gen : 88
# Best (in gen  88 ) : 1
# ********************
#
# position of Queens : [0, 5, 3, 6, 2, 7, 1, 4]
#
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# gen : 89
# Best (in gen  89 ) : 1
# ********************
#
# position of Queens : [0, 5, 3, 6, 2, 7, 1, 4]
#
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# gen : 90
# Best (in gen  90 ) : 1
# ********************
#
# position of Queens : [0, 5, 3, 6, 2, 7, 1, 4]
#
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# gen : 91
# Best (in gen  91 ) : 1
# ********************
#
# position of Queens : [0, 5, 3, 6, 2, 7, 1, 4]
#
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# gen : 92
# Best (in gen  92 ) : 1
# ********************
#
# position of Queens : [0, 5, 3, 6, 2, 7, 1, 4]
#
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# gen : 93
# Best (in gen  93 ) : 1
# ********************
#
# position of Queens : [0, 5, 3, 6, 2, 7, 1, 4]
#
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# gen : 94
# Best (in gen  94 ) : 1
# ********************
#
# position of Queens : [0, 5, 3, 6, 2, 7, 1, 4]
#
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# gen : 95
# Best (in gen  95 ) : 1
# ********************
#
# position of Queens : [0, 5, 3, 6, 2, 7, 1, 4]
#
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# gen : 96
# Best (in gen  96 ) : 1
# ********************
#
# position of Queens : [0, 5, 3, 6, 2, 7, 1, 4]
#
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# gen : 97
# Best (in gen  97 ) : 1
# ********************
#
# position of Queens : [0, 5, 3, 6, 2, 7, 1, 4]
#
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# gen : 98
# Best (in gen  98 ) : 1
# ********************
#
# position of Queens : [6, 4, 1, 0, 5, 7, 2, 0]
#
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', 'Q']
# gen : 99
# Best (in gen  99 ) : 1
# ********************
#
# position of Queens : [7, 2, 4, 2, 0, 6, 3, 1]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['_', 'Q', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# gen : 100
# Best (in gen  100 ) : 1
# ********************
#
# position of Queens : [7, 2, 4, 2, 0, 6, 3, 1]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['_', 'Q', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# gen : 101
# Best (in gen  101 ) : 1
# ********************
#
# position of Queens : [7, 2, 4, 2, 0, 6, 3, 1]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['_', 'Q', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# gen : 102
# Best (in gen  102 ) : 1
# ********************
#
# position of Queens : [7, 2, 1, 6, 0, 5, 0, 4]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', 'Q', '_']
# gen : 103
# Best (in gen  103 ) : 1
# ********************
#
# position of Queens : [7, 2, 1, 6, 0, 5, 0, 4]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', 'Q', '_']
# gen : 104
# Best (in gen  104 ) : 1
# ********************
#
# position of Queens : [0, 2, 5, 7, 2, 7, 3, 6]
#
# ['_', '_', '_', 'Q', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['_', 'Q', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# gen : 105
# Best (in gen  105 ) : 1
# ********************
#
# position of Queens : [0, 2, 5, 7, 2, 7, 3, 6]
#
# ['_', '_', '_', 'Q', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['_', 'Q', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# gen : 106
# Best (in gen  106 ) : 1
# ********************
#
# position of Queens : [0, 2, 5, 7, 2, 7, 3, 6]
#
# ['_', '_', '_', 'Q', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['_', 'Q', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# gen : 107
# Best (in gen  107 ) : 1
# ********************
#
# position of Queens : [0, 2, 5, 7, 2, 7, 3, 6]
#
# ['_', '_', '_', 'Q', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['_', 'Q', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# gen : 108
# Best (in gen  108 ) : 1
# ********************
#
# position of Queens : [0, 2, 5, 7, 2, 7, 3, 6]
#
# ['_', '_', '_', 'Q', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['_', 'Q', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# gen : 109
# Best (in gen  109 ) : 1
# ********************
#
# position of Queens : [7, 2, 1, 6, 0, 5, 0, 4]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', 'Q', '_']
# gen : 110
# Best (in gen  110 ) : 1
# ********************
#
# position of Queens : [7, 4, 6, 0, 2, 5, 3, 1]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# gen : 111
# Best (in gen  111 ) : 1
# ********************
#
# position of Queens : [7, 4, 6, 0, 2, 5, 3, 1]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# gen : 112
# Best (in gen  112 ) : 1
# ********************
#
# position of Queens : [7, 4, 6, 0, 2, 5, 3, 1]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# gen : 113
# Best (in gen  113 ) : 1
# ********************
#
# position of Queens : [7, 4, 6, 0, 2, 5, 3, 1]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# gen : 114
# Best (in gen  114 ) : 1
# ********************
#
# position of Queens : [7, 4, 6, 0, 2, 5, 3, 1]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# gen : 115
# Best (in gen  115 ) : 1
# ********************
#
# position of Queens : [7, 4, 6, 0, 2, 5, 3, 1]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# gen : 116
# Best (in gen  116 ) : 1
# ********************
#
# position of Queens : [7, 4, 6, 0, 2, 5, 3, 1]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# gen : 117
# Best (in gen  117 ) : 1
# ********************
#
# position of Queens : [7, 4, 6, 0, 2, 5, 3, 1]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# gen : 118
# Best (in gen  118 ) : 1
# ********************
#
# position of Queens : [7, 2, 4, 2, 0, 6, 3, 1]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# ['_', 'Q', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# gen : 119
# Best (in gen  119 ) : 1
# ********************
#
# position of Queens : [7, 2, 1, 6, 0, 5, 0, 4]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', 'Q', '_']
# gen : 120
# Best (in gen  120 ) : 1
# ********************
#
# position of Queens : [7, 2, 1, 6, 0, 5, 0, 4]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', 'Q', '_']
# gen : 121
# Best (in gen  121 ) : 1
# ********************
#
# position of Queens : [7, 2, 1, 6, 0, 5, 0, 4]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', 'Q', '_']
# gen : 122
# Best (in gen  122 ) : 1
# ********************
#
# position of Queens : [7, 2, 1, 6, 0, 5, 0, 4]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', 'Q', '_']
# gen : 123
# Best (in gen  123 ) : 1
# ********************
#
# position of Queens : [7, 2, 1, 6, 0, 5, 0, 4]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', 'Q', '_']
# gen : 124
# Best (in gen  124 ) : 1
# ********************
#
# position of Queens : [7, 2, 1, 6, 0, 5, 0, 4]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', 'Q', '_']
# gen : 125
# Best (in gen  125 ) : 1
# ********************
#
# position of Queens : [7, 2, 1, 6, 0, 5, 0, 4]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', 'Q', '_']
# gen : 126
# Best (in gen  126 ) : 1
# ********************
#
# position of Queens : [7, 2, 1, 6, 0, 5, 0, 4]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', 'Q', '_']
# gen : 127
# Best (in gen  127 ) : 1
# ********************
#
# position of Queens : [7, 2, 1, 6, 0, 5, 0, 4]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', 'Q', '_']
# gen : 128
# Best (in gen  128 ) : 1
# ********************
#
# position of Queens : [7, 2, 1, 6, 0, 5, 0, 4]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', 'Q', '_']
# gen : 129
# Best (in gen  129 ) : 1
# ********************
#
# position of Queens : [7, 2, 1, 6, 0, 5, 0, 4]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', 'Q', '_']
# gen : 130
# Best (in gen  130 ) : 1
# ********************
#
# position of Queens : [7, 2, 1, 6, 0, 5, 0, 4]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', 'Q', '_']
# gen : 131
# Best (in gen  131 ) : 1
# ********************
#
# position of Queens : [7, 2, 1, 6, 0, 5, 0, 4]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', 'Q', '_']
# gen : 132
# Best (in gen  132 ) : 1
# ********************
#
# position of Queens : [7, 2, 1, 6, 0, 5, 0, 4]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', 'Q', '_']
# gen : 133
# Best (in gen  133 ) : 1
# ********************
#
# position of Queens : [7, 2, 1, 6, 0, 5, 0, 4]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', 'Q', '_']
# gen : 134
# Best (in gen  134 ) : 1
# ********************
#
# position of Queens : [7, 2, 1, 6, 0, 5, 0, 4]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', 'Q', '_']
# gen : 135
# Best (in gen  135 ) : 1
# ********************
#
# position of Queens : [7, 2, 3, 6, 0, 5, 0, 4]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', 'Q', '_']
# gen : 136
# Best (in gen  136 ) : 1
# ********************
#
# position of Queens : [7, 2, 1, 6, 0, 5, 0, 4]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', 'Q', '_']
# gen : 137
# Best (in gen  137 ) : 1
# ********************
#
# position of Queens : [7, 2, 1, 6, 0, 5, 0, 4]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', 'Q', '_']
# gen : 138
# Best (in gen  138 ) : 1
# ********************
#
# position of Queens : [7, 2, 1, 6, 0, 5, 0, 4]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', 'Q', '_']
# gen : 139
# Best (in gen  139 ) : 1
# ********************
#
# position of Queens : [7, 2, 1, 6, 0, 5, 0, 4]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', 'Q', '_']
# gen : 140
# Best (in gen  140 ) : 1
# ********************
#
# position of Queens : [7, 2, 1, 6, 0, 5, 0, 4]
#
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', 'Q', '_']
# gen : 141
# Best (in gen  141 ) : 1
# ********************
#
# position of Queens : [5, 3, 1, 7, 4, 6, 0, 2]
#
# ['_', '_', '_', 'Q', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', 'Q', '_', '_']
# ['Q', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', 'Q', '_', '_', '_']
# ['_', 'Q', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', 'Q']
# ['_', '_', 'Q', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', 'Q', '_']
# gen : 142
# Best (in gen  142 ) : 0
# ********************
